# %% [markdown]
# <h2> Welcome to my github repository!</h2>

# %% [markdown]
# This file will be used for the coursera capstone project.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
